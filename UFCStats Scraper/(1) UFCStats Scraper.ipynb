# %%
# Updated as of 9/6/2024
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import csv


# Define headers for the HTTP request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'
}


def get_page_content(url):
    """
    Retrieve and parse HTML content from a specified URL using a user-defined number of retries.
    Returns a BeautifulSoup object if successful, otherwise None.

    Parameters:
    - url (str): The URL from which to fetch content.

    Returns:
    - BeautifulSoup: Parsed HTML of the page, or None if the request fails after retries.
    """
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return BeautifulSoup(response.content, 'html.parser')
        else:
            print(f"Failed to retrieve the page. Status code: {response.status_code}")
    except requests.RequestException as e:
        print(f"Request failed: {e}")

    print("All attempts failed. Returning None.")
    return None


def extract_event_info(event_element):
    """
    Extracts basic information for a given event element including name, link, date, and location.
    
    Parameters:
    - event_element (bs4.element.Tag): The BeautifulSoup tag for the event.

    Returns:
    - dict: A dictionary containing event name, link, formatted date, location, and an empty list for fights.
    """
    event_name = event_element.text.strip()
    event_link = event_element['href']
    
    # Extract date and location information
    event_date_str = event_element.find_next('span', class_='b-statistics__date').text.strip()
    event_location_str = event_element.find_next('td', class_='b-statistics__table-col b-statistics__table-col_style_big-top-padding').text.strip()
    
    # Format the date
    formatted_date = parse_date(event_date_str)
    
    # Create the event info dictionary
    event_info = {
        'name': event_name,
        'link': event_link,
        'date': formatted_date,
        'location': event_location_str,
        'fights': []  # Empty list to store fight information
    }
    
    # Retrieve event page content
    event_soup = get_page_content(event_info['link'])
    
    return event_info, event_soup


def parse_date(date_str):
    """
    Convert a date string into a specific format ('%m-%d-%Y'), unless it is 'N/A'.

    Parameters:
    - date_str (str): The date string to convert.

    Returns:
    - str: The formatted date or 'N/A' if input is 'N/A'.
    """
    if date_str != 'N/A':
        date_obj = datetime.strptime(date_str, '%B %d, %Y')
        return date_obj.strftime('%m-%d-%Y')
    else:
        return 'N/A'
    

def extract_fight_info(fight_row):
    """
    Extracts information about a specific fight, including fighter details, fight link, winner, and method of victory.
    
    Parameters:
    - fight_row (bs4.element.Tag): The BeautifulSoup tag containing the row with fight details.

    Returns:
    - dict: A dictionary containing the fight link, winner, method of victory, and fighter details.
    """
    # Extract fighter information
    fighter_a, fighter_b = extract_fighter_info(fight_row)
    
    # Check for fight link and winner determination
    fight_link, winner, method_of_victory = get_fight_link_and_winner(fight_row)
    
    return {
        'fight_link': fight_link,
        'winner': winner,
        'method_of_victory': method_of_victory,
        'fighter_a': fighter_a,
        'fighter_b': fighter_b
    }


def extract_fighter_info(fighter_row):
    """
    Extracts and returns basic information about two fighters from a table row.

    Parameters:
    - fighter_row (bs4.element.Tag): BeautifulSoup tag containing the row with fighter data.

    Returns:
    - tuple: Two dictionaries containing fighter names, their respective links, and empty rounds info.
    """
    fighters = [fighter.text.strip() for fighter in fighter_row.find_all('a', class_='b-link b-link_style_black')]
    fighter_links = [fighter['href'] for fighter in fighter_row.find_all('a', class_='b-link b-link_style_black')]
    
    return ({'name': fighters[0], 'link': fighter_links[0], 'rounds_a': []}, {'name': fighters[1], 'link': fighter_links[1], 'rounds_b': []})


def get_fight_link_and_winner(fight_row):
    """
    Determines the fight link and the winner based on the table row information.
    
    Parameters:
    - fight_row (bs4.element.Tag): BeautifulSoup tag containing the row with fight details.

    Returns:
    - tuple: (fight_link, winner, method_of_victory)
    """
    primary_fight_link_element = fight_row.find('a', class_='b-flag b-flag_style_green')
    
    if primary_fight_link_element:
        fight_link = primary_fight_link_element['href']
        winner = fight_row.find('a', class_='b-link b-link_style_black').text.strip()  # Assuming fighter A is the winner by default
        method_of_victory = 'TBD'
    else:
        alternative_fight_link_element = fight_row.find('a', class_='b-flag b-flag_style_bordered')
        fight_link = alternative_fight_link_element['href'] if alternative_fight_link_element else 'N/A'
        winner = 'N/A'  # No contest or no winner determined
        method_of_victory = 'NC' if fight_link == 'N/A' else 'TBD'
    
    return fight_link, winner, method_of_victory


def scrape_fight_info(fight_info):
    """
    Retrieves detailed fight information including rounds and results from the fight page, 
    then updates the fight_info dictionary.

    Parameters:
    - fight_info (dict): Dictionary containing basic information about the fight and links.
    """
    fight_url = fight_info['fight_link']
    fight_soup = get_page_content(fight_url)

    if not fight_soup:
        print(f"Failed to retrieve the fight page for {fight_info['fighter_a']['name']} vs {fight_info['fighter_b']['name']}. Skipping...")
        return

    weight_class_element = fight_soup.find('i', class_='b-fight-details__fight-title')
    weight_class = weight_class_element.text.strip() if weight_class_element else 'N/A'

    # Updating fight_info with the obtained data
    fight_info.update({
        'weight_class': weight_class,
        'title_fight': 'title' in weight_class.lower(),
        'gender': 'women' if 'women' in weight_class.lower() else 'men',
        'method_of_victory': fight_info.get('method_of_victory', 'N/A'),
        'round_of_victory': 'N/A',
        'time_in_ROV': 'N/A',
        'time_format': 'N/A',
        'referee': 'N/A'
    })

    if fight_info['method_of_victory'] != 'NC':  # Only update if not a 'No Contest'
        extract_victory_and_round_data(fight_soup, fight_info)

    # Parsing round information and strikes data
    rows_fighter_data = fight_soup.select('.b-fight-details__section.js-fight-section')[2].find('table', class_='b-fight-details__table').select('tbody > tr.b-fight-details__table-row')
    rows_strikes_data = fight_soup.select('.b-fight-details__section.js-fight-section')[4].find('table', class_='b-fight-details__table').select('tbody > tr.b-fight-details__table-row')

    for i, (row_fighter_data, row_strikes_data) in enumerate(zip(rows_fighter_data, rows_strikes_data), start=1):
        extract_round_data(row_fighter_data, row_strikes_data, fight_info['fighter_a']['name'], fight_info['fighter_b']['name'], fight_info)

    print(f"\nFight Summary for {fight_info['fighter_a']['name']} vs {fight_info['fighter_b']['name']}:")
    print(f"Winner: {fight_info['winner']}")
    print(f"Method of Victory: {fight_info['method_of_victory']}")
    print(f"Round of Victory: {fight_info['round_of_victory']}")
    print(f"Time of Victory: {fight_info['time_in_ROV']}")
    print(f"Time Format: {fight_info['time_format']}")
    print(f"Weight Class: {fight_info['weight_class']}")
    print(f"Referee: {fight_info['referee']}")
    print(f"Title Fight: {fight_info['title_fight']}")
    print(f"Gender: {fight_info['gender']}")
    print(f"Fight Link: {fight_info['fight_link']}")

        # Print rounds information for both fighters
    print("\nRounds Information:")
    for i, round_data in enumerate(fight_info['fighter_a']['rounds_a'], start=1):
        print(f"\nRound {i}:")
        print(f"Fighter A: {round_data}")
        print(f"\nFighter B: {fight_info['fighter_b']['rounds_b'][i-1]}")

        
def extract_victory_and_round_data(fight_soup, fight_info):
    """
    Extracts method of victory, round, time of victory, time format, and referee data from fight page.

    Parameters:
    - fight_soup (BeautifulSoup): Parsed HTML of the fight page.
    - fight_info (dict): Dictionary containing fight information to update.
    """
    method_victory_element = fight_soup.find('i', style='font-style: normal')
    if method_victory_element:
        fight_info['method_of_victory'] = method_victory_element.text.strip()

    round_element = fight_soup.find('i', class_='b-fight-details__text-item')
    if round_element and round_element.contents:
        fight_info['round_of_victory'] = round_element.contents[-1].strip()

        time_element = round_element.find_next('i', class_='b-fight-details__text-item')
        if time_element and time_element.contents:
            fight_info['time_in_ROV'] = time_element.contents[-1].strip()

            format_element = time_element.find_next('i', class_='b-fight-details__text-item')
            if format_element and format_element.contents:
                fight_info['time_format'] = format_element.contents[-1].strip()

                referee_element = format_element.find_next('span', class_='')
                if referee_element:
                    fight_info['referee'] = referee_element.text.strip()

                    
def extract_round_data(row_fighter_data, row_strikes_data, fighter_a_name, fighter_b_name, fight_info):
    """
    Extracts round-by-round data for both fighters and updates the fight_info dictionary.

    Parameters:
    - row_fighter_data (bs4.element.Tag): The row containing fighter-specific data.
    - row_strikes_data (bs4.element.Tag): The row containing strike-specific data.
    - fighter_a_name (str): Name of Fighter A.
    - fighter_b_name (str): Name of Fighter B.
    - fight_info (dict): The dictionary containing fight information to update.
    """
    fighter_one_data = extract_fighter_data(row_fighter_data, 0)
    fighter_two_data = extract_fighter_data(row_fighter_data, 1)
    fighter_one_strikes_data = extract_strikes_data(row_strikes_data, 0)
    fighter_two_strikes_data = extract_strikes_data(row_strikes_data, 1)

    fighter_one_data.update(fighter_one_strikes_data)
    fighter_two_data.update(fighter_two_strikes_data)

    if fighter_one_data['name'] == fighter_a_name:
        fight_info['fighter_a']['rounds_a'].append(fighter_one_data)
        fight_info['fighter_b']['rounds_b'].append(fighter_two_data)
    else:
        fight_info['fighter_a']['rounds_a'].append(fighter_two_data)
        fight_info['fighter_b']['rounds_b'].append(fighter_one_data)

        
def extract_fighter_data(row, index):
    """
    Extracts and returns detailed statistics of a fighter from a specific row in the table.

    Parameters:
    - row (bs4.element.Tag): The row from which to extract data.
    - index (int): Index to specify the fighter (0 for the first, 1 for the second).

    Returns:
    - dict: Dictionary containing various statistics for the fighter.
    """
    fighter_name_element = row.select('.b-fight-details__table-col.l-page_align_left a')
    fighter_name = fighter_name_element[index].text.strip() if fighter_name_element else 'N/A'

    knockdowns_element = row.select(f'.b-fight-details__table-col:nth-of-type(2) p')
    knockdowns = knockdowns_element[index].text.strip() if knockdowns_element else 'N/A'

    sig_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(3) p')
    sig_strikes = sig_strikes_element[index].text.strip() if sig_strikes_element else 'N/A'

    total_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(5) p')
    total_strikes = total_strikes_element[index].text.strip() if total_strikes_element else 'N/A'

    takedowns_element = row.select(f'.b-fight-details__table-col:nth-of-type(6) p')
    takedowns = takedowns_element[index].text.strip() if takedowns_element else 'N/A'

    sub_attempts_element = row.select(f'.b-fight-details__table-col:nth-of-type(8) p')
    sub_attempts = sub_attempts_element[index].text.strip() if sub_attempts_element else 'N/A'

    reversals_element = row.select(f'.b-fight-details__table-col:nth-of-type(9) p')
    reversals = reversals_element[index].text.strip() if reversals_element else 'N/A'

    control_time_element = row.select(f'.b-fight-details__table-col:nth-of-type(10) p')
    control_time = control_time_element[index].text.strip() if control_time_element else 'N/A'

    return {
        'name': fighter_name,
        'knockdowns': knockdowns,
        'sig_strikes': sig_strikes,
        'total_strikes': total_strikes,
        'takedowns': takedowns,
        'sub_attempts': sub_attempts,
        'reversals': reversals,
        'control_time': control_time,
    }


def extract_strikes_data(row, index):
    """
    Extracts detailed strikes data for a fighter from a specified row of the table.

    Parameters:
    - row (bs4.element.Tag): The BeautifulSoup tag of the row from which to extract data.
    - index (int): The index indicating which fighter's data to extract (0 for fighter_a, 1 for fighter_b).

    Returns:
    - dict: Dictionary containing various types of strikes information.
    """
    head_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(4) p')
    head_strikes = head_strikes_element[index].text.strip() if head_strikes_element else 'N/A'

    body_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(5) p')
    body_strikes = body_strikes_element[index].text.strip() if body_strikes_element else 'N/A'

    leg_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(6) p')
    leg_strikes = leg_strikes_element[index].text.strip() if leg_strikes_element else 'N/A'

    distance_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(7) p')
    distance_strikes = distance_strikes_element[index].text.strip() if distance_strikes_element else 'N/A'

    clinch_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(8) p')
    clinch_strikes = clinch_strikes_element[index].text.strip() if clinch_strikes_element else 'N/A'

    ground_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(9) p')
    ground_strikes = ground_strikes_element[index].text.strip() if ground_strikes_element else 'N/A'

    return {
        'head_strikes': head_strikes,
        'body_strikes': body_strikes,
        'leg_strikes': leg_strikes,
        'distance_strikes': distance_strikes,
        'clinch_strikes': clinch_strikes,
        'ground_strikes': ground_strikes,
    }


def scrape_fighter_info(fighter_info):
    """
    Scrapes and stores individual fighter details such as height, reach, and date of birth from the fighter's page.

    Parameters:
    - fighter_info (dict): Dictionary containing the fighter's name and link.
    """
    fighter_url = fighter_info['link']
    fighter_soup = get_page_content(fighter_url)

    if not fighter_soup:
        print(f"Failed to retrieve the fighter page for {fighter_info['name']}. Skipping...")
        return

    details_list = fighter_soup.find('ul', class_='b-list__box-list')
    details_items = details_list.find_all('li', class_='b-list__box-list-item')

    height_info = None
    reach_info = None
    dob_info = None

    for item in details_items:
        title = item.find('i', class_='b-list__box-item-title')
        if title:
            if 'Height' in title.text:
                height_info = item.contents[-1].strip()
            elif 'Reach' in title.text:
                reach_info = item.contents[-1].strip()
            elif 'DOB' in title.text:
                dob_info = item.contents[-1].strip()

    if height_info:
        fighter_info['height'] = {'feet_inches': height_info, 'inches': convert_to_inches(height_info)['inches']}
    else:
        fighter_info['height'] = {'feet_inches': 'N/A', 'inches': 'N/A'}

    if reach_info:
        fighter_info['reach'] = reach_info
    else:
        fighter_info['reach'] = 'N/A'

    if dob_info:
        dob_data = convert_to_numerical_date(dob_info)
        fighter_info['dob'] = dob_data['numerical_dob']
    else:
        fighter_info['dob'] = 'N/A'

    print(f"\nFighter Info for {fighter_info['name']}:")
    print(f"Height: {fighter_info['height']['feet_inches']}")
    print(f"Reach: {fighter_info['reach']}")
    print(f"Date of Birth: {fighter_info['dob']}")
    print(f"Fighter Link: {fighter_info['link']}")

    
def convert_to_inches(height_info):
    """
    Convert a height string from the format "feet'inches"" into inches only.

    Parameters:
    - height_info (str): The height string, e.g., "6'0"".

    Returns:
    - dict: Dictionary containing original and converted height information.
    """
    try:
        feet, inches = map(int, height_info.replace('"', '').split("'"))
        total_inches = feet * 12 + inches
        return {'feet_inches': f"{feet}' {inches}\"", 'inches': total_inches}
    except ValueError:
        return {'feet_inches': 'N/A', 'inches': 'N/A'}

    
def convert_to_numerical_date(date_str):
    """
    Convert a date string into a numerical format ('%m-%d-%Y').

    Parameters:
    - date_str (str): The date string to convert, in the format '%b %d, %Y'.

    Returns:
    - dict: Dictionary containing the converted date or 'N/A' if conversion fails.
    """
    try:
        date_obj = datetime.strptime(date_str, '%b %d, %Y')
        return {'numerical_dob': date_obj.strftime('%m-%d-%Y')}
    except ValueError:
        return {'numerical_dob': 'N/A'}

    
def write_to_csv(events_list):
    """
    Writes collected event data to a CSV file, including detailed round statistics for each fight.

    Parameters:
    - events_list (list): List of dictionaries, each representing an event and its associated fight data.
    """
    headers = [
        "event_name", "event_date", "event_location", "winner",
        "fighter_a_name", "fighter_b_name", "weightclass", "method_of_victory",
        "round_of_victory", "time_of_victory", "time_format", "referee",
        "title_fight", "gender", "fight_link", "fighter_a_height", "fighter_a_reach", "fighter_a_dob",
        "fighter_b_height", "fighter_b_reach", "fighter_b_dob"
    ]
    
    # Extend headers with round details for both fighters across five rounds
    rounds = 5
    for round_num in range(1, rounds + 1):
        for side in ['a', 'b']:
            prefix = f'rnd_{round_num}_{side}'
            headers.extend([
                f"{prefix}_knockdowns", f"{prefix}_sig_strikes", f"{prefix}_total_strikes",
                f"{prefix}_takedowns", f"{prefix}_sub_attemps", f"{prefix}_reversals",
                f"{prefix}_control_time", f"{prefix}_head_strikes", f"{prefix}_body_strikes",
                f"{prefix}_leg_strikes", f"{prefix}_distance_strikes", f"{prefix}_clinch_strikes",
                f"{prefix}_ground_strikes"
            ])

    with open('event_masterlist.csv', 'w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(headers)

        for event in events_list:
            for fight in event['fights']:
                row = [
                    event['name'], event['date'], event['location'], fight['winner'],
                    fight['fighter_a']['name'], fight['fighter_b']['name'],
                    fight['weight_class'], fight['method_of_victory'],
                    fight['round_of_victory'], fight['time_in_ROV'], fight['time_format'],
                    fight['referee'], fight['title_fight'], fight['gender'],
                    fight['fight_link'], fight['fighter_a'].get('height', {}).get('inches', 'NaN'),
                    fight['fighter_a'].get('reach', 'NaN'), fight['fighter_a'].get('dob', 'NaN'),
                    fight['fighter_b'].get('height', {}).get('inches', 'NaN'),
                    fight['fighter_b'].get('reach', 'NaN'),
                    fight['fighter_b'].get('dob', 'NaN')
                ]
                
                # Adding round details for each fighter
                for round_num in range(1, rounds + 1):
                    for side in ['a', 'b']:
                        round_data = fight.get(f'fighter_{side}').get(f'rounds_{side}', [])
                        if len(round_data) >= round_num:
                            round_stats = round_data[round_num - 1]
                            row.extend([
                                round_stats.get('knockdowns', 'NaN'),
                                round_stats.get('sig_strikes', 'NaN'),
                                round_stats.get('total_strikes', 'NaN'),
                                round_stats.get('takedowns', 'NaN'),
                                round_stats.get('sub_attempts', 'NaN'),
                                round_stats.get('reversals', 'NaN'),
                                round_stats.get('control_time', 'NaN'),
                                round_stats.get('head_strikes', 'NaN'),
                                round_stats.get('body_strikes', 'NaN'),
                                round_stats.get('leg_strikes', 'NaN'),
                                round_stats.get('distance_strikes', 'NaN'),
                                round_stats.get('clinch_strikes', 'NaN'),
                                round_stats.get('ground_strikes', 'NaN')
                            ])
                        else:
                            row.extend(['NaN'] * 13)  # Add NaN for all round stats if round data is missing

                writer.writerow(row)

                
def main():
    """
    Main function to orchestrate the web scraping process, including retrieving event data,
    scraping fight details and individual fighter stats, and finally writing all data to a CSV file.
    
    Returns:
    - list: List of dictionaries with detailed event and fight information (used for writing to CSV).
    """
    try:
        # URL of the main page listing all completed events
        url = 'http://www.ufcstats.com/statistics/events/completed?page=all'
        soup = get_page_content(url)

        # Check if the main page content was successfully retrieved
        if soup:
            event_elements = soup.find_all('a', class_='b-link b-link_style_black')
            events_list = []

            # Iterate over each event link found on the main page
            for event_element in event_elements:
                event_info, event_soup = extract_event_info(event_element)

                # Check if the event page content was successfully retrieved
                if event_soup:
                    fight_rows = event_soup.find_all('tr', class_='b-fight-details__table-row')[1:]  # Skip the header row which contains a future event

                    # Iterate over fight rows and extract fight information
                    for fight_row in fight_rows:
                        fight_info = extract_fight_info(fight_row)
                        event_info['fights'].append(fight_info)

                    events_list.append(event_info)

            # Process each event and associated fights to scrape detailed information
            for event_info in events_list:
                print(f"\nEvent: {event_info['name']}")
                print(f"Date: {event_info['date']}")
                print(f"Location: {event_info['location']}")

                for fight_info in event_info['fights']:
                    scrape_fight_info(fight_info)
                    scrape_fighter_info(fight_info['fighter_a'])
                    scrape_fighter_info(fight_info['fighter_b'])

        # Return the populated event list, useful for unit testing or further processing
        return events_list

    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        # Always attempt to save data to CSV, even if an error occurs
        if events_list:
            print("Saving data to CSV due to an error or normal completion.")
            write_to_csv(events_list)

            
if __name__ == "__main__":
    # Script entry point, calls the main function to start the process
    events_list = main()
    write_to_csv(events_list)  # Ensure data is saved at the end of processing

    
# Small clerical note:
# I'm not sure why, but there is a delay in start time. You must run the cell and then wait, sometimes upwards
# of 5 minutes, for the scraping to begin. I couldn't figure out how to fix this, but it does
# work. I promise. You just have to be patient. I apologize for any inconvenience.
# Out:
# Event: UFC Fight Night: Cannonier vs. Borralho
# Date: 08-24-2024
# Location: Las Vegas, Nevada, USA
#
# Fight Summary for Caio Borralho vs Jared Cannonier:
# Winner: Caio Borralho
# Method of Victory: Decision - Unanimous
# Round of Victory: 5
# Time of Victory: 5:00
# Time Format: 5 Rnd (5-5-5-5-5)
# Weight Class: Middleweight Bout
# Referee: Dan Miragliotta
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/15805ae1eea3343e
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Caio Borralho', 'knockdowns': '0', 'sig_strikes': '15 of 32', 'total_strikes': '15 of 32', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '7 of 22', 'body_strikes': '4 of 6', 'leg_strikes': '4 of 4', 'distance_strikes': '15 of 32', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Jared Cannonier', 'knockdowns': '0', 'sig_strikes': '12 of 34', 'total_strikes': '12 of 34', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '4 of 23', 'body_strikes': '2 of 2', 'leg_strikes': '6 of 9', 'distance_strikes': '12 of 34', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Caio Borralho', 'knockdowns': '0', 'sig_strikes': '21 of 43', 'total_strikes': '21 of 43', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '14 of 34', 'body_strikes': '2 of 4', 'leg_strikes': '5 of 5', 'distance_strikes': '21 of 43', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Jared Cannonier', 'knockdowns': '0', 'sig_strikes': '26 of 70', 'total_strikes': '26 of 70', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '18 of 53', 'body_strikes': '4 of 9', 'leg_strikes': '4 of 8', 'distance_strikes': '25 of 69', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Caio Borralho', 'knockdowns': '0', 'sig_strikes': '37 of 58', 'total_strikes': '37 of 58', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:05', 'head_strikes': '24 of 44', 'body_strikes': '10 of 11', 'leg_strikes': '3 of 3', 'distance_strikes': '36 of 56', 'clinch_strikes': '1 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Jared Cannonier', 'knockdowns': '0', 'sig_strikes': '15 of 58', 'total_strikes': '15 of 58', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '14 of 54', 'body_strikes': '0 of 1', 'leg_strikes': '1 of 3', 'distance_strikes': '15 of 58', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 4:
# Fighter A: {'name': 'Caio Borralho', 'knockdowns': '0', 'sig_strikes': '30 of 53', 'total_strikes': '30 of 53', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '19 of 37', 'body_strikes': '5 of 10', 'leg_strikes': '6 of 6', 'distance_strikes': '30 of 53', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Jared Cannonier', 'knockdowns': '0', 'sig_strikes': '19 of 50', 'total_strikes': '19 of 50', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '11 of 38', 'body_strikes': '4 of 8', 'leg_strikes': '4 of 4', 'distance_strikes': '19 of 50', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 5:
# Fighter A: {'name': 'Caio Borralho', 'knockdowns': '1', 'sig_strikes': '50 of 69', 'total_strikes': '53 of 72', 'takedowns': '0 of 1', 'sub_attempts': '1', 'reversals': '0', 'control_time': '1:54', 'head_strikes': '42 of 60', 'body_strikes': '5 of 6', 'leg_strikes': '3 of 3', 'distance_strikes': '27 of 40', 'clinch_strikes': '1 of 1', 'ground_strikes': '22 of 28'}
#
# Fighter B: {'name': 'Jared Cannonier', 'knockdowns': '0', 'sig_strikes': '11 of 42', 'total_strikes': '11 of 42', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '10 of 38', 'body_strikes': '1 of 4', 'leg_strikes': '0 of 0', 'distance_strikes': '11 of 41', 'clinch_strikes': '0 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Caio Borralho:
# Height: 6' 1"
# Reach: 75"
# Date of Birth: 01-16-1993
# Fighter Link: http://www.ufcstats.com/fighter-details/4126a78111c0855a
#
# Fighter Info for Jared Cannonier:
# Height: 5' 11"
# Reach: 77"
# Date of Birth: 03-16-1984
# Fighter Link: http://www.ufcstats.com/fighter-details/13a0275fa13c4d26
#
# Fight Summary for Tabatha Ricci vs Angela Hill:
# Winner: Tabatha Ricci
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Women's Strawweight Bout
# Referee: Keith Peterson
# Title Fight: False
# Gender: women
# Fight Link: http://www.ufcstats.com/fight-details/70afe9e0d2422252
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Tabatha Ricci', 'knockdowns': '0', 'sig_strikes': '27 of 62', 'total_strikes': '42 of 78', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:07', 'head_strikes': '18 of 52', 'body_strikes': '4 of 5', 'leg_strikes': '5 of 5', 'distance_strikes': '20 of 53', 'clinch_strikes': '7 of 9', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Angela Hill', 'knockdowns': '0', 'sig_strikes': '21 of 47', 'total_strikes': '35 of 61', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:05', 'head_strikes': '10 of 34', 'body_strikes': '11 of 13', 'leg_strikes': '0 of 0', 'distance_strikes': '14 of 37', 'clinch_strikes': '7 of 10', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Tabatha Ricci', 'knockdowns': '0', 'sig_strikes': '35 of 76', 'total_strikes': '44 of 86', 'takedowns': '2 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:58', 'head_strikes': '29 of 67', 'body_strikes': '2 of 5', 'leg_strikes': '4 of 4', 'distance_strikes': '31 of 68', 'clinch_strikes': '1 of 2', 'ground_strikes': '3 of 6'}
#
# Fighter B: {'name': 'Angela Hill', 'knockdowns': '0', 'sig_strikes': '44 of 79', 'total_strikes': '51 of 87', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '27 of 52', 'body_strikes': '14 of 24', 'leg_strikes': '3 of 3', 'distance_strikes': '32 of 62', 'clinch_strikes': '8 of 10', 'ground_strikes': '4 of 7'}
#
# Round 3:
# Fighter A: {'name': 'Tabatha Ricci', 'knockdowns': '0', 'sig_strikes': '39 of 101', 'total_strikes': '54 of 116', 'takedowns': '1 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:59', 'head_strikes': '35 of 96', 'body_strikes': '2 of 3', 'leg_strikes': '2 of 2', 'distance_strikes': '37 of 98', 'clinch_strikes': '2 of 3', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Angela Hill', 'knockdowns': '0', 'sig_strikes': '47 of 90', 'total_strikes': '54 of 97', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:05', 'head_strikes': '29 of 66', 'body_strikes': '18 of 24', 'leg_strikes': '0 of 0', 'distance_strikes': '42 of 83', 'clinch_strikes': '4 of 6', 'ground_strikes': '1 of 1'}
#
# Fighter Info for Tabatha Ricci:
# Height: 5' 1"
# Reach: 61"
# Date of Birth: 02-21-1995
# Fighter Link: http://www.ufcstats.com/fighter-details/d25240135aee03e5
#
# Fighter Info for Angela Hill:
# Height: 5' 3"
# Reach: 64"
# Date of Birth: 01-12-1985
# Fighter Link: http://www.ufcstats.com/fighter-details/f0feeb2192937424
#
# Fight Summary for Ryan Loder vs Robert Valentin:
# Winner: Ryan Loder
# Method of Victory: KO/TKO
# Round of Victory: 2
# Time of Victory: 1:49
# Time Format: 3 Rnd + OT (5-5-5-5)
# Weight Class: Middleweight Bout
# Referee: Mark Smith
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/5c5523a6bf83e44f
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Ryan Loder', 'knockdowns': '0', 'sig_strikes': '4 of 5', 'total_strikes': '20 of 21', 'takedowns': '1 of 2', 'sub_attempts': '1', 'reversals': '1', 'control_time': '3:08', 'head_strikes': '3 of 4', 'body_strikes': '1 of 1', 'leg_strikes': '0 of 0', 'distance_strikes': '1 of 1', 'clinch_strikes': '0 of 0', 'ground_strikes': '3 of 4'}
#
# Fighter B: {'name': 'Robert Valentin', 'knockdowns': '0', 'sig_strikes': '0 of 1', 'total_strikes': '3 of 4', 'takedowns': '0 of 0', 'sub_attempts': '2', 'reversals': '1', 'control_time': '1:38', 'head_strikes': '0 of 1', 'body_strikes': '0 of 0', 'leg_strikes': '0 of 0', 'distance_strikes': '0 of 1', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Ryan Loder', 'knockdowns': '0', 'sig_strikes': '38 of 47', 'total_strikes': '43 of 52', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:37', 'head_strikes': '38 of 47', 'body_strikes': '0 of 0', 'leg_strikes': '0 of 0', 'distance_strikes': '0 of 1', 'clinch_strikes': '0 of 0', 'ground_strikes': '38 of 46'}
#
# Fighter B: {'name': 'Robert Valentin', 'knockdowns': '0', 'sig_strikes': '1 of 1', 'total_strikes': '2 of 2', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '1 of 1', 'body_strikes': '0 of 0', 'leg_strikes': '0 of 0', 'distance_strikes': '1 of 1', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Ryan Loder:
# Height: 6' 2"
# Reach: 76"
# Date of Birth: 06-05-1991
# Fighter Link: http://www.ufcstats.com/fighter-details/d5bab53a1a603aac
#
# Fighter Info for Robert Valentin:
# Height: 6' 2"
# Reach: 77"
# Date of Birth: 03-31-1995
# Fighter Link: http://www.ufcstats.com/fighter-details/0cd0456d6029cec2
#
# Fight Summary for Mairon Santos vs Kaan Ofli:
# Winner: Mairon Santos
# Method of Victory: KO/TKO
# Round of Victory: 2
# Time of Victory: 1:30
# Time Format: 3 Rnd + OT (5-5-5-5)
# Weight Class: Featherweight Bout
# Referee: Chris Tognoni
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/bad06a5380d762b8
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Mairon Santos', 'knockdowns': '0', 'sig_strikes': '19 of 43', 'total_strikes': '20 of 44', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '9 of 33', 'body_strikes': '6 of 6', 'leg_strikes': '4 of 4', 'distance_strikes': '18 of 41', 'clinch_strikes': '1 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Kaan Ofli', 'knockdowns': '0', 'sig_strikes': '7 of 20', 'total_strikes': '14 of 27', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:29', 'head_strikes': '7 of 17', 'body_strikes': '0 of 1', 'leg_strikes': '0 of 2', 'distance_strikes': '7 of 20', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Mairon Santos', 'knockdowns': '1', 'sig_strikes': '12 of 24', 'total_strikes': '12 of 24', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:02', 'head_strikes': '6 of 15', 'body_strikes': '3 of 6', 'leg_strikes': '3 of 3', 'distance_strikes': '9 of 21', 'clinch_strikes': '0 of 0', 'ground_strikes': '3 of 3'}
#
# Fighter B: {'name': 'Kaan Ofli', 'knockdowns': '0', 'sig_strikes': '5 of 8', 'total_strikes': '5 of 8', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:04', 'head_strikes': '3 of 5', 'body_strikes': '1 of 1', 'leg_strikes': '1 of 2', 'distance_strikes': '4 of 7', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Mairon Santos:
# Height: 5' 7"
# Reach: 72"
# Date of Birth: 06-10-2000
# Fighter Link: http://www.ufcstats.com/fighter-details/480779d7f9a424d3
#
# Fighter Info for Kaan Ofli:
# Height: 5' 7"
# Reach: 66"
# Date of Birth: 06-19-1993
# Fighter Link: http://www.ufcstats.com/fighter-details/7facc9c45d792985
#
# Fight Summary for Michael Morales vs Neil Magny:
# Winner: Michael Morales
# Method of Victory: KO/TKO
# Round of Victory: 1
# Time of Victory: 4:39
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Welterweight Bout
# Referee: Dan Miragliotta
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/ae50a1a655b1a8f6
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Michael Morales', 'knockdowns': '1', 'sig_strikes': '34 of 40', 'total_strikes': '39 of 45', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:16', 'head_strikes': '30 of 35', 'body_strikes': '0 of 0', 'leg_strikes': '4 of 5', 'distance_strikes': '4 of 5', 'clinch_strikes': '0 of 0', 'ground_strikes': '30 of 35'}
#
# Fighter B: {'name': 'Neil Magny', 'knockdowns': '0', 'sig_strikes': '5 of 11', 'total_strikes': '13 of 19', 'takedowns': '0 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:05', 'head_strikes': '1 of 7', 'body_strikes': '2 of 2', 'leg_strikes': '2 of 2', 'distance_strikes': '3 of 8', 'clinch_strikes': '1 of 2', 'ground_strikes': '1 of 1'}
#
# Fighter Info for Michael Morales:
# Height: 6' 0"
# Reach: 79"
# Date of Birth: 06-24-1999
# Fighter Link: http://www.ufcstats.com/fighter-details/c32aeb1a59e6272d
#
# Fighter Info for Neil Magny:
# Height: 6' 3"
# Reach: 80"
# Date of Birth: 08-03-1987
# Fighter Link: http://www.ufcstats.com/fighter-details/84b3e7d38f2d2ec5
#
# Fight Summary for Gerald Meerschaert vs Edmen Shahbazyan:
# Winner: Gerald Meerschaert
# Method of Victory: Submission
# Round of Victory: 2
# Time of Victory: 4:12
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Middleweight Bout
# Referee: Mark Smith
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/2cbd53e43d3f606b
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Gerald Meerschaert', 'knockdowns': '0', 'sig_strikes': '14 of 33', 'total_strikes': '16 of 35', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '5 of 24', 'body_strikes': '5 of 5', 'leg_strikes': '4 of 4', 'distance_strikes': '14 of 33', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Edmen Shahbazyan', 'knockdowns': '0', 'sig_strikes': '22 of 50', 'total_strikes': '22 of 50', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:03', 'head_strikes': '12 of 38', 'body_strikes': '9 of 11', 'leg_strikes': '1 of 1', 'distance_strikes': '21 of 46', 'clinch_strikes': '1 of 4', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Gerald Meerschaert', 'knockdowns': '0', 'sig_strikes': '7 of 11', 'total_strikes': '15 of 19', 'takedowns': '1 of 5', 'sub_attempts': '1', 'reversals': '0', 'control_time': '0:21', 'head_strikes': '6 of 9', 'body_strikes': '1 of 2', 'leg_strikes': '0 of 0', 'distance_strikes': '6 of 9', 'clinch_strikes': '1 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Edmen Shahbazyan', 'knockdowns': '0', 'sig_strikes': '26 of 63', 'total_strikes': '26 of 63', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:18', 'head_strikes': '19 of 56', 'body_strikes': '7 of 7', 'leg_strikes': '0 of 0', 'distance_strikes': '5 of 14', 'clinch_strikes': '4 of 5', 'ground_strikes': '17 of 44'}
#
# Fighter Info for Gerald Meerschaert:
# Height: 6' 1"
# Reach: 77"
# Date of Birth: 12-18-1987
# Fighter Link: http://www.ufcstats.com/fighter-details/6ac9bc2953c47345
#
# Fighter Info for Edmen Shahbazyan:
# Height: 6' 3"
# Reach: 75"
# Date of Birth: 11-20-1997
# Fighter Link: http://www.ufcstats.com/fighter-details/4144798612ef96e5
#
# Fight Summary for Francis Marshall vs Dennis Buzukja:
# Winner: Francis Marshall
# Method of Victory: Decision - Split
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Lightweight Bout
# Referee: Keith Peterson
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/560f1e26c2a6690a
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Francis Marshall', 'knockdowns': '0', 'sig_strikes': '6 of 19', 'total_strikes': '25 of 38', 'takedowns': '1 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '3:56', 'head_strikes': '6 of 19', 'body_strikes': '0 of 0', 'leg_strikes': '0 of 0', 'distance_strikes': '6 of 19', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Dennis Buzukja', 'knockdowns': '0', 'sig_strikes': '6 of 16', 'total_strikes': '11 of 22', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '2 of 10', 'body_strikes': '3 of 4', 'leg_strikes': '1 of 2', 'distance_strikes': '6 of 16', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Francis Marshall', 'knockdowns': '1', 'sig_strikes': '23 of 56', 'total_strikes': '28 of 61', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:01', 'head_strikes': '21 of 53', 'body_strikes': '1 of 2', 'leg_strikes': '1 of 1', 'distance_strikes': '21 of 52', 'clinch_strikes': '1 of 2', 'ground_strikes': '1 of 2'}
#
# Fighter B: {'name': 'Dennis Buzukja', 'knockdowns': '0', 'sig_strikes': '30 of 52', 'total_strikes': '33 of 55', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '22 of 37', 'body_strikes': '4 of 11', 'leg_strikes': '4 of 4', 'distance_strikes': '30 of 51', 'clinch_strikes': '0 of 1', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Francis Marshall', 'knockdowns': '0', 'sig_strikes': '28 of 75', 'total_strikes': '29 of 76', 'takedowns': '0 of 3', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:29', 'head_strikes': '26 of 72', 'body_strikes': '1 of 2', 'leg_strikes': '1 of 1', 'distance_strikes': '26 of 73', 'clinch_strikes': '2 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Dennis Buzukja', 'knockdowns': '0', 'sig_strikes': '30 of 77', 'total_strikes': '32 of 79', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:08', 'head_strikes': '22 of 63', 'body_strikes': '7 of 12', 'leg_strikes': '1 of 2', 'distance_strikes': '29 of 76', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Francis Marshall:
# Height: 5' 9"
# Reach: 72"
# Date of Birth: 03-03-1999
# Fighter Link: http://www.ufcstats.com/fighter-details/5d495dec23d7c68e
#
# Fighter Info for Dennis Buzukja:
# Height: 5' 9"
# Reach: 70"
# Date of Birth: 10-01-1997
# Fighter Link: http://www.ufcstats.com/fighter-details/c4d039123e62f6a9
#
# Fight Summary for Zachary Reese vs Jose Daniel Medina:
# Winner: Zachary Reese
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Middleweight Bout
# Referee: Dan Miragliotta
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/d2caa1ddb9de7481
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Zachary Reese', 'knockdowns': '0', 'sig_strikes': '34 of 54', 'total_strikes': '40 of 63', 'takedowns': '1 of 3', 'sub_attempts': '1', 'reversals': '1', 'control_time': '2:08', 'head_strikes': '23 of 42', 'body_strikes': '9 of 10', 'leg_strikes': '2 of 2', 'distance_strikes': '20 of 33', 'clinch_strikes': '1 of 2', 'ground_strikes': '13 of 19'}
#
# Fighter B: {'name': 'Jose Daniel Medina', 'knockdowns': '0', 'sig_strikes': '4 of 15', 'total_strikes': '13 of 26', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:46', 'head_strikes': '2 of 11', 'body_strikes': '0 of 2', 'leg_strikes': '2 of 2', 'distance_strikes': '4 of 15', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Zachary Reese', 'knockdowns': '0', 'sig_strikes': '26 of 53', 'total_strikes': '31 of 58', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '10 of 31', 'body_strikes': '8 of 13', 'leg_strikes': '8 of 9', 'distance_strikes': '26 of 53', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Jose Daniel Medina', 'knockdowns': '0', 'sig_strikes': '18 of 41', 'total_strikes': '20 of 43', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:26', 'head_strikes': '11 of 29', 'body_strikes': '2 of 7', 'leg_strikes': '5 of 5', 'distance_strikes': '18 of 41', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Zachary Reese', 'knockdowns': '0', 'sig_strikes': '15 of 22', 'total_strikes': '30 of 41', 'takedowns': '4 of 6', 'sub_attempts': '0', 'reversals': '0', 'control_time': '3:49', 'head_strikes': '9 of 12', 'body_strikes': '3 of 7', 'leg_strikes': '3 of 3', 'distance_strikes': '11 of 15', 'clinch_strikes': '1 of 2', 'ground_strikes': '3 of 5'}
#
# Fighter B: {'name': 'Jose Daniel Medina', 'knockdowns': '0', 'sig_strikes': '10 of 18', 'total_strikes': '20 of 28', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '7 of 15', 'body_strikes': '3 of 3', 'leg_strikes': '0 of 0', 'distance_strikes': '8 of 16', 'clinch_strikes': '1 of 1', 'ground_strikes': '1 of 1'}
#
# Fighter Info for Zachary Reese:
# Height: 6' 4"
# Reach: 77"
# Date of Birth: 03-24-1994
# Fighter Link: http://www.ufcstats.com/fighter-details/23dec7c47cb418f8
#
# Fighter Info for Jose Daniel Medina:
# Height: 6' 0"
# Reach: 74"
# Date of Birth: 05-17-1991
# Fighter Link: http://www.ufcstats.com/fighter-details/baa9be02c3e3e038
#
# Fight Summary for Viacheslav Borshchev vs James Llontop:
# Winner: Viacheslav Borshchev
# Method of Victory: Decision - Split
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Lightweight Bout
# Referee: Chris Tognoni
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/ba8eda6993922ba0
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Viacheslav Borshchev', 'knockdowns': '0', 'sig_strikes': '26 of 61', 'total_strikes': '27 of 62', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '9 of 39', 'body_strikes': '11 of 14', 'leg_strikes': '6 of 8', 'distance_strikes': '24 of 59', 'clinch_strikes': '2 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'James Llontop', 'knockdowns': '0', 'sig_strikes': '26 of 63', 'total_strikes': '26 of 63', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:03', 'head_strikes': '10 of 41', 'body_strikes': '5 of 9', 'leg_strikes': '11 of 13', 'distance_strikes': '24 of 60', 'clinch_strikes': '1 of 2', 'ground_strikes': '1 of 1'}
#
# Round 2:
# Fighter A: {'name': 'Viacheslav Borshchev', 'knockdowns': '0', 'sig_strikes': '37 of 85', 'total_strikes': '37 of 85', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:03', 'head_strikes': '19 of 63', 'body_strikes': '11 of 15', 'leg_strikes': '7 of 7', 'distance_strikes': '36 of 83', 'clinch_strikes': '0 of 0', 'ground_strikes': '1 of 2'}
#
# Fighter B: {'name': 'James Llontop', 'knockdowns': '0', 'sig_strikes': '25 of 77', 'total_strikes': '25 of 77', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '11 of 56', 'body_strikes': '9 of 12', 'leg_strikes': '5 of 9', 'distance_strikes': '25 of 76', 'clinch_strikes': '0 of 1', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Viacheslav Borshchev', 'knockdowns': '0', 'sig_strikes': '33 of 83', 'total_strikes': '33 of 83', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '21 of 70', 'body_strikes': '8 of 9', 'leg_strikes': '4 of 4', 'distance_strikes': '32 of 81', 'clinch_strikes': '1 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'James Llontop', 'knockdowns': '0', 'sig_strikes': '42 of 109', 'total_strikes': '46 of 113', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:02', 'head_strikes': '19 of 71', 'body_strikes': '13 of 23', 'leg_strikes': '10 of 15', 'distance_strikes': '42 of 108', 'clinch_strikes': '0 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Viacheslav Borshchev:
# Height: 5' 11"
# Reach: 69"
# Date of Birth: 01-08-1992
# Fighter Link: http://www.ufcstats.com/fighter-details/19c591115a58982c
#
# Fighter Info for James Llontop:
# Height: 6' 0"
# Reach: 73"
# Date of Birth: 08-02-1999
# Fighter Link: http://www.ufcstats.com/fighter-details/93b2b7caa457cbea
#
# Fight Summary for Jacqueline Cavalcanti vs Josiane Nunes:
# Winner: Jacqueline Cavalcanti
# Method of Victory: Decision - Split
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Women's Bantamweight Bout
# Referee: Mark Smith
# Title Fight: False
# Gender: women
# Fight Link: http://www.ufcstats.com/fight-details/903d588b30a471e8
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Jacqueline Cavalcanti', 'knockdowns': '0', 'sig_strikes': '34 of 62', 'total_strikes': '34 of 62', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '17 of 42', 'body_strikes': '6 of 8', 'leg_strikes': '11 of 12', 'distance_strikes': '34 of 62', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Josiane Nunes', 'knockdowns': '0', 'sig_strikes': '20 of 52', 'total_strikes': '20 of 52', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '8 of 37', 'body_strikes': '6 of 9', 'leg_strikes': '6 of 6', 'distance_strikes': '20 of 52', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Jacqueline Cavalcanti', 'knockdowns': '0', 'sig_strikes': '31 of 60', 'total_strikes': '31 of 60', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '15 of 41', 'body_strikes': '4 of 7', 'leg_strikes': '12 of 12', 'distance_strikes': '31 of 60', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Josiane Nunes', 'knockdowns': '0', 'sig_strikes': '18 of 48', 'total_strikes': '18 of 48', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '12 of 39', 'body_strikes': '4 of 7', 'leg_strikes': '2 of 2', 'distance_strikes': '18 of 48', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Jacqueline Cavalcanti', 'knockdowns': '0', 'sig_strikes': '26 of 49', 'total_strikes': '26 of 49', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '17 of 36', 'body_strikes': '1 of 4', 'leg_strikes': '8 of 9', 'distance_strikes': '26 of 49', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Josiane Nunes', 'knockdowns': '0', 'sig_strikes': '14 of 53', 'total_strikes': '14 of 53', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:08', 'head_strikes': '13 of 50', 'body_strikes': '1 of 3', 'leg_strikes': '0 of 0', 'distance_strikes': '12 of 49', 'clinch_strikes': '0 of 0', 'ground_strikes': '2 of 4'}
#
# Fighter Info for Jacqueline Cavalcanti:
# Height: 5' 8"
# Reach: 70"
# Date of Birth: 08-29-1997
# Fighter Link: http://www.ufcstats.com/fighter-details/e3964ece586e0635
#
# Fighter Info for Josiane Nunes:
# Height: 5' 2"
# Reach: 67"
# Date of Birth: 12-23-1993
# Fighter Link: http://www.ufcstats.com/fighter-details/68d35296f566792b
#
# Fight Summary for Wang Cong vs Victoria Leonardo:
# Winner: Wang Cong
# Method of Victory: KO/TKO
# Round of Victory: 1
# Time of Victory: 1:02
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Women's Flyweight Bout
# Referee: Chris Tognoni
# Title Fight: False
# Gender: women
# Fight Link: http://www.ufcstats.com/fight-details/d4127baf74b0e791
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Wang Cong', 'knockdowns': '1', 'sig_strikes': '10 of 26', 'total_strikes': '10 of 26', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:02', 'head_strikes': '4 of 16', 'body_strikes': '1 of 5', 'leg_strikes': '5 of 5', 'distance_strikes': '10 of 26', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Victoria Leonardo', 'knockdowns': '0', 'sig_strikes': '1 of 9', 'total_strikes': '1 of 9', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '0 of 7', 'body_strikes': '0 of 1', 'leg_strikes': '1 of 1', 'distance_strikes': '1 of 9', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Wang Cong:
# Height: 5' 6"
# Reach: 66"
# Date of Birth: 05-15-1992
# Fighter Link: http://www.ufcstats.com/fighter-details/2997e7fe3c9d3d4a
#
# Fighter Info for Victoria Leonardo:
# Height: 5' 5"
# Reach: 64"
# Date of Birth: 02-16-1990
# Fighter Link: http://www.ufcstats.com/fighter-details/9dedfdd91070ddd8
#
# Event: UFC 305: Du Plessis vs. Adesanya
# Date: 08-17-2024
# Location: Perth, Western Australia, Australia
#
# Fight Summary for Dricus Du Plessis vs Israel Adesanya:
# Winner: Dricus Du Plessis
# Method of Victory: Submission
# Round of Victory: 4
# Time of Victory: 3:38
# Time Format: 5 Rnd (5-5-5-5-5)
# Weight Class: UFC Middleweight Title Bout
# Referee: Marc Goddard
# Title Fight: True
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/6c44af21414e4143
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Dricus Du Plessis', 'knockdowns': '0', 'sig_strikes': '22 of 52', 'total_strikes': '22 of 52', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '8 of 30', 'body_strikes': '2 of 5', 'leg_strikes': '12 of 17', 'distance_strikes': '22 of 52', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Israel Adesanya', 'knockdowns': '0', 'sig_strikes': '16 of 37', 'total_strikes': '16 of 37', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '10 of 31', 'body_strikes': '4 of 4', 'leg_strikes': '2 of 2', 'distance_strikes': '16 of 37', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Dricus Du Plessis', 'knockdowns': '0', 'sig_strikes': '13 of 25', 'total_strikes': '22 of 34', 'takedowns': '3 of 5', 'sub_attempts': '1', 'reversals': '0', 'control_time': '3:28', 'head_strikes': '10 of 21', 'body_strikes': '2 of 2', 'leg_strikes': '1 of 2', 'distance_strikes': '5 of 14', 'clinch_strikes': '6 of 9', 'ground_strikes': '2 of 2'}
#
# Fighter B: {'name': 'Israel Adesanya', 'knockdowns': '0', 'sig_strikes': '17 of 30', 'total_strikes': '25 of 38', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '1', 'control_time': '0:02', 'head_strikes': '12 of 25', 'body_strikes': '2 of 2', 'leg_strikes': '3 of 3', 'distance_strikes': '13 of 26', 'clinch_strikes': '4 of 4', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Dricus Du Plessis', 'knockdowns': '0', 'sig_strikes': '31 of 75', 'total_strikes': '31 of 75', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '22 of 63', 'body_strikes': '1 of 3', 'leg_strikes': '8 of 9', 'distance_strikes': '31 of 75', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Israel Adesanya', 'knockdowns': '0', 'sig_strikes': '40 of 83', 'total_strikes': '40 of 83', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '25 of 66', 'body_strikes': '12 of 14', 'leg_strikes': '3 of 3', 'distance_strikes': '40 of 83', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 4:
# Fighter A: {'name': 'Dricus Du Plessis', 'knockdowns': '0', 'sig_strikes': '24 of 45', 'total_strikes': '24 of 45', 'takedowns': '1 of 2', 'sub_attempts': '1', 'reversals': '0', 'control_time': '0:11', 'head_strikes': '21 of 41', 'body_strikes': '2 of 3', 'leg_strikes': '1 of 1', 'distance_strikes': '22 of 43', 'clinch_strikes': '2 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Israel Adesanya', 'knockdowns': '0', 'sig_strikes': '24 of 53', 'total_strikes': '24 of 53', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:07', 'head_strikes': '16 of 43', 'body_strikes': '8 of 9', 'leg_strikes': '0 of 1', 'distance_strikes': '23 of 52', 'clinch_strikes': '0 of 0', 'ground_strikes': '1 of 1'}
#
# Fighter Info for Dricus Du Plessis:
# Height: 6' 1"
# Reach: 76"
# Date of Birth: 01-14-1994
# Fighter Link: http://www.ufcstats.com/fighter-details/0d7b51c9d2649a6e
#
# Fighter Info for Israel Adesanya:
# Height: 6' 4"
# Reach: 80"
# Date of Birth: 07-22-1989
# Fighter Link: http://www.ufcstats.com/fighter-details/1338e2c7480bdf9e
#
# Fight Summary for Kai Kara-France vs Steve Erceg:
# Winner: Kai Kara-France
# Method of Victory: KO/TKO
# Round of Victory: 1
# Time of Victory: 4:04
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Flyweight Bout
# Referee: Rich Mitchell
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/bf8c5effd23f69c4
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Kai Kara-France', 'knockdowns': '2', 'sig_strikes': '18 of 51', 'total_strikes': '18 of 51', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:08', 'head_strikes': '11 of 35', 'body_strikes': '5 of 13', 'leg_strikes': '2 of 3', 'distance_strikes': '15 of 44', 'clinch_strikes': '0 of 0', 'ground_strikes': '3 of 7'}
#
# Fighter B: {'name': 'Steve Erceg', 'knockdowns': '0', 'sig_strikes': '9 of 29', 'total_strikes': '9 of 29', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '8 of 26', 'body_strikes': '0 of 2', 'leg_strikes': '1 of 1', 'distance_strikes': '9 of 29', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Kai Kara-France:
# Height: 5' 4"
# Reach: 69"
# Date of Birth: 03-26-1993
# Fighter Link: http://www.ufcstats.com/fighter-details/853eb0dd5c0e2149
#
# Fighter Info for Steve Erceg:
# Height: 5' 8"
# Reach: 68"
# Date of Birth: 07-27-1995
# Fighter Link: http://www.ufcstats.com/fighter-details/32ab52e5de93092d
#
# Fight Summary for Dan Hooker vs Mateusz Gamrot:
# Winner: Dan Hooker
# Method of Victory: Decision - Split
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Lightweight Bout
# Referee: Jim Perdios
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/059f5cf0e9e37627
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Dan Hooker', 'knockdowns': '0', 'sig_strikes': '20 of 43', 'total_strikes': '24 of 47', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:17', 'head_strikes': '9 of 28', 'body_strikes': '11 of 15', 'leg_strikes': '0 of 0', 'distance_strikes': '15 of 38', 'clinch_strikes': '1 of 1', 'ground_strikes': '4 of 4'}
#
# Fighter B: {'name': 'Mateusz Gamrot', 'knockdowns': '0', 'sig_strikes': '26 of 54', 'total_strikes': '31 of 59', 'takedowns': '2 of 4', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:31', 'head_strikes': '22 of 50', 'body_strikes': '2 of 2', 'leg_strikes': '2 of 2', 'distance_strikes': '9 of 28', 'clinch_strikes': '2 of 2', 'ground_strikes': '15 of 24'}
#
# Round 2:
# Fighter A: {'name': 'Dan Hooker', 'knockdowns': '0', 'sig_strikes': '17 of 34', 'total_strikes': '27 of 46', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:44', 'head_strikes': '12 of 26', 'body_strikes': '5 of 8', 'leg_strikes': '0 of 0', 'distance_strikes': '7 of 23', 'clinch_strikes': '1 of 1', 'ground_strikes': '9 of 10'}
#
# Fighter B: {'name': 'Mateusz Gamrot', 'knockdowns': '0', 'sig_strikes': '11 of 17', 'total_strikes': '27 of 34', 'takedowns': '2 of 4', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:37', 'head_strikes': '8 of 13', 'body_strikes': '3 of 4', 'leg_strikes': '0 of 0', 'distance_strikes': '7 of 11', 'clinch_strikes': '0 of 0', 'ground_strikes': '4 of 6'}
#
# Round 3:
# Fighter A: {'name': 'Dan Hooker', 'knockdowns': '0', 'sig_strikes': '28 of 66', 'total_strikes': '31 of 69', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:27', 'head_strikes': '20 of 57', 'body_strikes': '8 of 9', 'leg_strikes': '0 of 0', 'distance_strikes': '22 of 58', 'clinch_strikes': '2 of 4', 'ground_strikes': '4 of 4'}
#
# Fighter B: {'name': 'Mateusz Gamrot', 'knockdowns': '0', 'sig_strikes': '27 of 58', 'total_strikes': '30 of 61', 'takedowns': '1 of 7', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:51', 'head_strikes': '26 of 56', 'body_strikes': '1 of 2', 'leg_strikes': '0 of 0', 'distance_strikes': '27 of 58', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Dan Hooker:
# Height: 6' 0"
# Reach: 75"
# Date of Birth: 02-13-1990
# Fighter Link: http://www.ufcstats.com/fighter-details/193b9d1858bc4df3
#
# Fighter Info for Mateusz Gamrot:
# Height: 5' 10"
# Reach: 70"
# Date of Birth: 12-11-1990
# Fighter Link: http://www.ufcstats.com/fighter-details/72db2a14ffa73ece
#
# Fight Summary for Jairzinho Rozenstruik vs Tai Tuivasa:
# Winner: Jairzinho Rozenstruik
# Method of Victory: Decision - Split
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Heavyweight Bout
# Referee: Marc Goddard
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/dd3d8f7066c145b7
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Jairzinho Rozenstruik', 'knockdowns': '0', 'sig_strikes': '19 of 48', 'total_strikes': '19 of 48', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '5 of 32', 'body_strikes': '4 of 6', 'leg_strikes': '10 of 10', 'distance_strikes': '19 of 48', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Tai Tuivasa', 'knockdowns': '0', 'sig_strikes': '9 of 38', 'total_strikes': '9 of 38', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '1 of 22', 'body_strikes': '2 of 5', 'leg_strikes': '6 of 11', 'distance_strikes': '9 of 38', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Jairzinho Rozenstruik', 'knockdowns': '0', 'sig_strikes': '36 of 69', 'total_strikes': '37 of 70', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '27 of 57', 'body_strikes': '4 of 6', 'leg_strikes': '5 of 6', 'distance_strikes': '33 of 65', 'clinch_strikes': '3 of 4', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Tai Tuivasa', 'knockdowns': '0', 'sig_strikes': '13 of 38', 'total_strikes': '13 of 38', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:01', 'head_strikes': '8 of 28', 'body_strikes': '1 of 6', 'leg_strikes': '4 of 4', 'distance_strikes': '13 of 37', 'clinch_strikes': '0 of 1', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Jairzinho Rozenstruik', 'knockdowns': '0', 'sig_strikes': '36 of 67', 'total_strikes': '36 of 67', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:01', 'head_strikes': '26 of 57', 'body_strikes': '4 of 4', 'leg_strikes': '6 of 6', 'distance_strikes': '34 of 64', 'clinch_strikes': '2 of 3', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Tai Tuivasa', 'knockdowns': '0', 'sig_strikes': '15 of 50', 'total_strikes': '15 of 50', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '10 of 42', 'body_strikes': '3 of 6', 'leg_strikes': '2 of 2', 'distance_strikes': '15 of 49', 'clinch_strikes': '0 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Jairzinho Rozenstruik:
# Height: 6' 2"
# Reach: 78"
# Date of Birth: 03-17-1988
# Fighter Link: http://www.ufcstats.com/fighter-details/2cd428e9606856fd
#
# Fighter Info for Tai Tuivasa:
# Height: 6' 2"
# Reach: 75"
# Date of Birth: 03-16-1993
# Fighter Link: http://www.ufcstats.com/fighter-details/c62fbc117d57b943
#
# Fight Summary for Carlos Prates vs Li Jingliang:
# Winner: Carlos Prates
# Method of Victory: KO/TKO
# Round of Victory: 2
# Time of Victory: 4:02
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Welterweight Bout
# Referee: Matt Wynne
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/3c319d4659e6c8fd
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Carlos Prates', 'knockdowns': '1', 'sig_strikes': '25 of 36', 'total_strikes': '25 of 36', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '18 of 27', 'body_strikes': '1 of 2', 'leg_strikes': '6 of 7', 'distance_strikes': '25 of 36', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Li Jingliang', 'knockdowns': '0', 'sig_strikes': '26 of 66', 'total_strikes': '26 of 66', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '7 of 38', 'body_strikes': '4 of 9', 'leg_strikes': '15 of 19', 'distance_strikes': '26 of 66', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Carlos Prates', 'knockdowns': '2', 'sig_strikes': '30 of 48', 'total_strikes': '30 of 48', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '26 of 43', 'body_strikes': '0 of 1', 'leg_strikes': '4 of 4', 'distance_strikes': '30 of 48', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Li Jingliang', 'knockdowns': '0', 'sig_strikes': '15 of 45', 'total_strikes': '15 of 45', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:23', 'head_strikes': '5 of 26', 'body_strikes': '0 of 1', 'leg_strikes': '10 of 18', 'distance_strikes': '15 of 45', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Carlos Prates:
# Height: 6' 1"
# Reach: 78"
# Date of Birth: 08-17-1993
# Fighter Link: http://www.ufcstats.com/fighter-details/7ee0fd831c0fe7c3
#
# Fighter Info for Li Jingliang:
# Height: 6' 0"
# Reach: 71"
# Date of Birth: 03-20-1988
# Fighter Link: http://www.ufcstats.com/fighter-details/e64b96c07d7ce999
#
# Fight Summary for Valter Walker vs Junior Tafa:
# Winner: Valter Walker
# Method of Victory: Submission
# Round of Victory: 1
# Time of Victory: 4:56
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Heavyweight Bout
# Referee: Steve Perceval
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/ea4ff1d77928b029
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Valter Walker', 'knockdowns': '0', 'sig_strikes': '4 of 4', 'total_strikes': '20 of 23', 'takedowns': '2 of 3', 'sub_attempts': '1', 'reversals': '0', 'control_time': '3:54', 'head_strikes': '1 of 1', 'body_strikes': '0 of 0', 'leg_strikes': '3 of 3', 'distance_strikes': '3 of 3', 'clinch_strikes': '0 of 0', 'ground_strikes': '1 of 1'}
#
# Fighter B: {'name': 'Junior Tafa', 'knockdowns': '0', 'sig_strikes': '5 of 8', 'total_strikes': '10 of 13', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '4 of 7', 'body_strikes': '1 of 1', 'leg_strikes': '0 of 0', 'distance_strikes': '4 of 7', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Valter Walker:
# Height: 6' 6"
# Reach: 78"
# Date of Birth: 12-14-1997
# Fighter Link: http://www.ufcstats.com/fighter-details/f5779a2303ed76ec
#
# Fighter Info for Junior Tafa:
# Height: 6' 3"
# Reach: 75"
# Date of Birth: 09-21-1996
# Fighter Link: http://www.ufcstats.com/fighter-details/c15fa95b9a12fde4
#
# Fight Summary for Ricardo Ramos vs Josh Culibao:
# Winner: Ricardo Ramos
# Method of Victory: Decision - Split
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Featherweight Bout
# Referee: Matt Wynne
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/43ebfc8914a39061
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Ricardo Ramos', 'knockdowns': '0', 'sig_strikes': '2 of 31', 'total_strikes': '3 of 32', 'takedowns': '0 of 0', 'sub_attempts': '1', 'reversals': '0', 'control_time': '2:41', 'head_strikes': '1 of 21', 'body_strikes': '0 of 2', 'leg_strikes': '1 of 8', 'distance_strikes': '2 of 31', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Josh Culibao', 'knockdowns': '0', 'sig_strikes': '10 of 21', 'total_strikes': '20 of 31', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:02', 'head_strikes': '3 of 13', 'body_strikes': '2 of 2', 'leg_strikes': '5 of 6', 'distance_strikes': '10 of 21', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Ricardo Ramos', 'knockdowns': '0', 'sig_strikes': '10 of 33', 'total_strikes': '12 of 39', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '5 of 28', 'body_strikes': '2 of 2', 'leg_strikes': '3 of 3', 'distance_strikes': '10 of 33', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Josh Culibao', 'knockdowns': '1', 'sig_strikes': '34 of 61', 'total_strikes': '36 of 64', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:28', 'head_strikes': '19 of 43', 'body_strikes': '1 of 2', 'leg_strikes': '14 of 16', 'distance_strikes': '23 of 47', 'clinch_strikes': '0 of 0', 'ground_strikes': '11 of 14'}
#
# Round 3:
# Fighter A: {'name': 'Ricardo Ramos', 'knockdowns': '0', 'sig_strikes': '15 of 54', 'total_strikes': '24 of 63', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:28', 'head_strikes': '10 of 43', 'body_strikes': '4 of 7', 'leg_strikes': '1 of 4', 'distance_strikes': '13 of 52', 'clinch_strikes': '2 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Josh Culibao', 'knockdowns': '0', 'sig_strikes': '26 of 45', 'total_strikes': '36 of 55', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '18 of 35', 'body_strikes': '6 of 6', 'leg_strikes': '2 of 4', 'distance_strikes': '25 of 44', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Ricardo Ramos:
# Height: 5' 9"
# Reach: 72"
# Date of Birth: 08-01-1995
# Fighter Link: http://www.ufcstats.com/fighter-details/1ae8f3c723aacff4
#
# Fighter Info for Josh Culibao:
# Height: 5' 10"
# Reach: 73"
# Date of Birth: 05-24-1994
# Fighter Link: http://www.ufcstats.com/fighter-details/6751eacd16bd59bc
#
# Fight Summary for Casey O'Neill vs Luana Santos:
# Winner: Casey O'Neill
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Women's Flyweight Bout
# Referee: Rich Mitchell
# Title Fight: False
# Gender: women
# Fight Link: http://www.ufcstats.com/fight-details/b9d5c77ae7a8109b
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': "Casey O'Neill", 'knockdowns': '0', 'sig_strikes': '24 of 54', 'total_strikes': '29 of 59', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '15 of 44', 'body_strikes': '3 of 4', 'leg_strikes': '6 of 6', 'distance_strikes': '23 of 53', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Luana Santos', 'knockdowns': '0', 'sig_strikes': '16 of 34', 'total_strikes': '20 of 38', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:16', 'head_strikes': '10 of 25', 'body_strikes': '4 of 7', 'leg_strikes': '2 of 2', 'distance_strikes': '16 of 33', 'clinch_strikes': '0 of 1', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': "Casey O'Neill", 'knockdowns': '0', 'sig_strikes': '25 of 62', 'total_strikes': '28 of 66', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:10', 'head_strikes': '19 of 51', 'body_strikes': '4 of 9', 'leg_strikes': '2 of 2', 'distance_strikes': '21 of 56', 'clinch_strikes': '4 of 6', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Luana Santos', 'knockdowns': '0', 'sig_strikes': '12 of 32', 'total_strikes': '13 of 33', 'takedowns': '1 of 4', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:05', 'head_strikes': '7 of 23', 'body_strikes': '4 of 8', 'leg_strikes': '1 of 1', 'distance_strikes': '12 of 30', 'clinch_strikes': '0 of 2', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': "Casey O'Neill", 'knockdowns': '0', 'sig_strikes': '34 of 77', 'total_strikes': '56 of 102', 'takedowns': '0 of 0', 'sub_attempts': '1', 'reversals': '0', 'control_time': '2:11', 'head_strikes': '26 of 68', 'body_strikes': '5 of 6', 'leg_strikes': '3 of 3', 'distance_strikes': '25 of 68', 'clinch_strikes': '0 of 0', 'ground_strikes': '9 of 9'}
#
# ...
#
# Fighter B: {'name': 'Cody Brundage', 'knockdowns': '0', 'sig_strikes': '1 of 2', 'total_strikes': '1 of 2', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:03', 'head_strikes': '1 of 2', 'body_strikes': '0 of 0', 'leg_strikes': '0 of 0', 'distance_strikes': '1 of 2', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Abdul Razak Alhassan:
# Height: 5' 10"
# Reach: 73"
# Date of Birth: 08-11-1985
# Fighter Link: http://www.ufcstats.com/fighter-details/eae431e70064e046
#
# Fighter Info for Cody Brundage:
# Height: 6' 0"
# Reach: 72"
# Date of Birth: 05-16-1994
# Fighter Link: http://www.ufcstats.com/fighter-details/f14f644d41ade29f
#
# Fight Summary for Charles Johnson vs Joshua Van:
# Winner: Charles Johnson
# Method of Victory: KO/TKO
# Round of Victory: 3
# Time of Victory: 0:20
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Flyweight Bout
# Referee: Joe Coca
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/80108a70c4afa6c2
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Charles Johnson', 'knockdowns': '0', 'sig_strikes': '44 of 80', 'total_strikes': '46 of 83', 'takedowns': '0 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:32', 'head_strikes': '18 of 41', 'body_strikes': '13 of 23', 'leg_strikes': '13 of 16', 'distance_strikes': '41 of 74', 'clinch_strikes': '3 of 6', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Joshua Van', 'knockdowns': '0', 'sig_strikes': '22 of 46', 'total_strikes': '27 of 53', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:15', 'head_strikes': '13 of 36', 'body_strikes': '8 of 9', 'leg_strikes': '1 of 1', 'distance_strikes': '16 of 37', 'clinch_strikes': '6 of 8', 'ground_strikes': '0 of 1'}
#
# Round 2:
# Fighter A: {'name': 'Charles Johnson', 'knockdowns': '0', 'sig_strikes': '36 of 100', 'total_strikes': '36 of 101', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '19 of 74', 'body_strikes': '11 of 16', 'leg_strikes': '6 of 10', 'distance_strikes': '36 of 100', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Joshua Van', 'knockdowns': '0', 'sig_strikes': '44 of 83', 'total_strikes': '44 of 83', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '30 of 66', 'body_strikes': '9 of 11', 'leg_strikes': '5 of 6', 'distance_strikes': '43 of 82', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Charles Johnson', 'knockdowns': '1', 'sig_strikes': '8 of 11', 'total_strikes': '8 of 11', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:02', 'head_strikes': '7 of 9', 'body_strikes': '1 of 2', 'leg_strikes': '0 of 0', 'distance_strikes': '7 of 10', 'clinch_strikes': '0 of 0', 'ground_strikes': '1 of 1'}
#
# Fighter B: {'name': 'Joshua Van', 'knockdowns': '0', 'sig_strikes': '1 of 4', 'total_strikes': '1 of 4', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '1 of 4', 'body_strikes': '0 of 0', 'leg_strikes': '0 of 0', 'distance_strikes': '1 of 4', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Charles Johnson:
# Height: 5' 9"
# Reach: 70"
# Date of Birth: 01-10-1991
# Fighter Link: http://www.ufcstats.com/fighter-details/814e5233e2acf2ee
#
# Fighter Info for Joshua Van:
# Height: 5' 5"
# Reach: 65"
# Date of Birth: 10-10-2001
# Fighter Link: http://www.ufcstats.com/fighter-details/17e97649403ba428
#
# Fight Summary for Jasmine Jasudavicius vs Fatima Kline:
# Winner: Jasmine Jasudavicius
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Women's Flyweight Bout
# Referee: Joel Ojeda
# Title Fight: False
# Gender: women
# Fight Link: http://www.ufcstats.com/fight-details/582afc25875911d1
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Jasmine Jasudavicius', 'knockdowns': '0', 'sig_strikes': '10 of 23', 'total_strikes': '31 of 55', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:32', 'head_strikes': '7 of 17', 'body_strikes': '0 of 3', 'leg_strikes': '3 of 3', 'distance_strikes': '5 of 15', 'clinch_strikes': '0 of 0', 'ground_strikes': '5 of 8'}
#
# Fighter B: {'name': 'Fatima Kline', 'knockdowns': '0', 'sig_strikes': '4 of 12', 'total_strikes': '6 of 14', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:37', 'head_strikes': '2 of 10', 'body_strikes': '0 of 0', 'leg_strikes': '2 of 2', 'distance_strikes': '4 of 12', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Jasmine Jasudavicius', 'knockdowns': '0', 'sig_strikes': '17 of 29', 'total_strikes': '29 of 49', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:25', 'head_strikes': '9 of 18', 'body_strikes': '6 of 9', 'leg_strikes': '2 of 2', 'distance_strikes': '11 of 22', 'clinch_strikes': '4 of 5', 'ground_strikes': '2 of 2'}
#
# Fighter B: {'name': 'Fatima Kline', 'knockdowns': '0', 'sig_strikes': '16 of 31', 'total_strikes': '19 of 36', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:15', 'head_strikes': '13 of 27', 'body_strikes': '3 of 4', 'leg_strikes': '0 of 0', 'distance_strikes': '11 of 25', 'clinch_strikes': '2 of 3', 'ground_strikes': '3 of 3'}
#
# Round 3:
# Fighter A: {'name': 'Jasmine Jasudavicius', 'knockdowns': '0', 'sig_strikes': '13 of 37', 'total_strikes': '33 of 61', 'takedowns': '2 of 4', 'sub_attempts': '1', 'reversals': '0', 'control_time': '2:51', 'head_strikes': '9 of 30', 'body_strikes': '3 of 6', 'leg_strikes': '1 of 1', 'distance_strikes': '11 of 33', 'clinch_strikes': '0 of 1', 'ground_strikes': '2 of 3'}
#
# Fighter B: {'name': 'Fatima Kline', 'knockdowns': '0', 'sig_strikes': '19 of 38', 'total_strikes': '23 of 44', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '17 of 36', 'body_strikes': '2 of 2', 'leg_strikes': '0 of 0', 'distance_strikes': '18 of 37', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Jasmine Jasudavicius:
# Height: 5' 7"
# Reach: 68"
# Date of Birth: 03-01-1989
# Fighter Link: http://www.ufcstats.com/fighter-details/a9e260472d321361
#
# Fighter Info for Fatima Kline:
# Height: 5' 6"
# Reach: 67"
# Date of Birth: 07-12-2000
# Fighter Link: http://www.ufcstats.com/fighter-details/745fa7b605f8e2da
#
# Fight Summary for Montel Jackson vs Da'Mon Blackshear:
# Winner: Montel Jackson
# Method of Victory: KO/TKO
# Round of Victory: 1
# Time of Victory: 0:18
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Bantamweight Bout
# Referee: Nick Berens
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/5eebde8fb4d67259
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Montel Jackson', 'knockdowns': '1', 'sig_strikes': '4 of 6', 'total_strikes': '4 of 6', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:02', 'head_strikes': '4 of 5', 'body_strikes': '0 of 1', 'leg_strikes': '0 of 0', 'distance_strikes': '1 of 3', 'clinch_strikes': '0 of 0', 'ground_strikes': '3 of 3'}
#
# Fighter B: {'name': "Da'Mon Blackshear", 'knockdowns': '0', 'sig_strikes': '1 of 1', 'total_strikes': '1 of 1', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '0 of 0', 'body_strikes': '0 of 0', 'leg_strikes': '1 of 1', 'distance_strikes': '1 of 1', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Montel Jackson:
# Height: 5' 10"
# Reach: 75"
# Date of Birth: 04-24-1992
# Fighter Link: http://www.ufcstats.com/fighter-details/cc1a8b4b38b92c6d
#
# Fighter Info for Da'Mon Blackshear:
# Height: 5' 10"
# Reach: 72"
# Date of Birth: 08-12-1994
# Fighter Link: http://www.ufcstats.com/fighter-details/da22387a0407a2dc
#
# Fight Summary for Luana Santos vs Mariya Agapova:
# Winner: Luana Santos
# Method of Victory: Submission
# Round of Victory: 1
# Time of Victory: 3:27
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Women's Flyweight Bout
# Referee: Joe Coca
# Title Fight: False
# Gender: women
# Fight Link: http://www.ufcstats.com/fight-details/e06bfd0100eccbad
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Luana Santos', 'knockdowns': '0', 'sig_strikes': '2 of 4', 'total_strikes': '9 of 12', 'takedowns': '1 of 1', 'sub_attempts': '3', 'reversals': '0', 'control_time': '2:23', 'head_strikes': '2 of 4', 'body_strikes': '0 of 0', 'leg_strikes': '0 of 0', 'distance_strikes': '2 of 4', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Mariya Agapova', 'knockdowns': '0', 'sig_strikes': '3 of 14', 'total_strikes': '20 of 31', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '1 of 5', 'body_strikes': '0 of 2', 'leg_strikes': '2 of 7', 'distance_strikes': '3 of 14', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Luana Santos:
# Height: 5' 6"
# Reach: 67"
# Date of Birth: 04-16-2000
# Fighter Link: http://www.ufcstats.com/fighter-details/5078e1dacf9d25f4
#
# Fighter Info for Mariya Agapova:
# Height: 5' 6"
# Reach: 68"
# Date of Birth: 04-07-1997
# Fighter Link: http://www.ufcstats.com/fighter-details/a08ddd04eaffd81d
# Saving data to CSV due to an error or normal completion.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 544, in main()
#     543 for fight_info in event_info['fights']:
# --> 544     scrape_fight_info(fight_info)
#     545     scrape_fighter_info(fight_info['fighter_a'])
#
# Cell In[6], line 157, in scrape_fight_info(fight_info)
#     156 fight_url = fight_info['fight_link']
# --> 157 fight_soup = get_page_content(fight_url)
#     159 if not fight_soup:
#
# Cell In[6], line 24, in get_page_content(url)
#      23 try:
# ---> 24     response = requests.get(url, headers=headers)
#      25     if response.status_code == 200:
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
#     462 except BaseException as e:
#     463     # Remove the TypeError from the exception chain in
#     464     # Python 3 (including for exceptions like SystemExit).
#     465     # Otherwise it looks like a bug in the code.
#
# File ~\anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File ~\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
#     707 except timeout:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 561
#     557             write_to_csv(events_list)
#     559 if __name__ == "__main__":
#     560     # Script entry point, calls the main function to start the process
# --> 561     events_list = main()
#     562     write_to_csv(events_list)
#
# Cell In[6], line 557, in main()
#     555 if events_list:
#     556     print("Saving data to CSV due to an error or normal completion.")
# --> 557     write_to_csv(events_list)
#
# Cell In[6], line 468, in write_to_csv(events_list)
#     463 for event in events_list:
#     464     for fight in event['fights']:
#     465         row = [
#     466             event['name'], event['date'], event['location'], fight['winner'],
#     467             fight['fighter_a']['name'], fight['fighter_b']['name'],
# --> 468             fight['weight_class'], fight['method_of_victory'],
#     469             fight['round_of_victory'], fight['time_in_ROV'], fight['time_format'],
#     470             fight['referee'], fight['title_fight'], fight['gender'],
#     471             fight['fight_link'], fight['fighter_a'].get('height', {}).get('inches', 'NaN'),
#     472             fight['fighter_a'].get('reach', 'NaN'), fight['fighter_a'].get('dob', 'NaN'),
#     473             fight['fighter_b'].get('height', {}).get('inches', 'NaN'),
#     474             fight['fighter_b'].get('reach', 'NaN'),
#     475             fight['fighter_b'].get('dob', 'NaN')
#     476         ]
#     478         # Adding round details for each fighter
#     479         for round_num in range(1, rounds + 1):
#
# KeyError: 'weight_class'
